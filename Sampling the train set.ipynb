# %%
import pandas as pd
import pyspark as ps
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-bfed13843e7a> in <module>()
#       1 import pandas as pd
# ----> 2 import pyspark as ps
#
# ImportError: No module named pyspark

# %%
data_path = '/home/raku/kaggleData/quora/'

# %%
train_df = pd.read_csv(data_path+'train.csv')

# %%
print train_df.shape
# Out:
# (404290, 6)

# %%
sample_df = train_df.sample(frac=0.01,random_state = 3333)

# %%
sample_df.to_csv(data_path+'sample.csv',index=False)

# %%
sample_df
# Out:
#             id    qid1    qid2  \
# 38876    38876   70542   70543
# 162389  162389  252807  252808
# 126433  126433   32893  120009
# 386494  386494  429006  518699
# 18289    18289   34659   34660
# 163788  163788  254668  254669
# 67983    67983  101402   41311
# 249072  249072  362619  362620
# 317152  317152  442310  150136
# 267002  267002  384273  384274
# 164707  164707  255872  255873
# 379287  379287   19487   80914
# 283494  283494  152191   55582
# 75164    75164  128687  128688
# 350816  350816  479584  278103
# 223794  223794  331701  331702
# 382397  382397  514235  514236
# 96967    96967  161422  161423
# 389064  389064  521514  521515
# 315258  315258  440127  440128
# 243369  243369  355791  355792
# 79629    79629  135537  135538
# 216830  216830  323057  323058
# 97988    97988  162914  162915
# 215687  215687  321641  321642
# 113201  113201  185062  185063
# 22603    22603   42403   42404
# 400174  400174  135816  374374
# 26947    26947   50092   50093
# ...

# %%
#testing the sampel
sampel_test = pd.read_csv(data_path+'sample.csv')

# %%
sampel_test
# Out:
#           id    qid1    qid2  \
# 0      38876   70542   70543
# 1     162389  252807  252808
# 2     126433   32893  120009
# 3     386494  429006  518699
# 4      18289   34659   34660
# 5     163788  254668  254669
# 6      67983  101402   41311
# 7     249072  362619  362620
# 8     317152  442310  150136
# 9     267002  384273  384274
# 10    164707  255872  255873
# 11    379287   19487   80914
# 12    283494  152191   55582
# 13     75164  128687  128688
# 14    350816  479584  278103
# 15    223794  331701  331702
# 16    382397  514235  514236
# 17     96967  161422  161423
# 18    389064  521514  521515
# 19    315258  440127  440128
# 20    243369  355791  355792
# 21     79629  135537  135538
# 22    216830  323057  323058
# 23     97988  162914  162915
# 24    215687  321641  321642
# 25    113201  185062  185063
# 26     22603   42403   42404
# 27    400174  135816  374374
# 28     26947   50092   50093
# 29    337153  464599  464600
# ...      ...     ...     ...
# ...
